# %%
import pandas as pd
from sklearn.metrics import mean_absolute_percentage_error, r2_score, mean_absolute_error

from analytics.machine_learning.price_prediction_with_fundamentals import utils

# %%
dataset = utils.get_dataset(only_value_change_columns=True)

# %%
dataset['avg_next_three_months_price'].describe()
# Out:
# count    52633.000000
# mean        68.113406
# std        153.437300
# min          0.113538
# 25%         15.354615
# 50%         33.767692
# 75%         72.607500
# max       6211.739167
# Name: avg_next_three_months_price, dtype: float64

# %%
dataset.columns
# Out:
# Index(['change_in_cash_and_cash_equivalents', 'change_in_exchange_rate',
#        'accumulated_depreciation_amortization_ppe_value_change',
#        'capital_expenditures_value_change',
#        'capital_lease_obligations_value_change',
#        'cash_and_cash_equivalents_at_carrying_value_value_change',
#        'cash_and_short_term_investments_value_change',
#        'cashflow_from_financing_value_change',
#        'cashflow_from_investment_value_change',
#        'change_in_inventory_value_change',
#        'change_in_operating_assets_value_change',
#        'change_in_operating_liabilities_value_change',
#        'change_in_receivables_value_change', 'common_stock_value_change',
#        'common_stock_shares_outstanding_value_change',
#        'comprehensive_income_net_of_tax_value_change',
#        'cost_of_goods_and_services_sold_value_change',
#        'cost_of_revenue_value_change', 'current_accounts_payable_value_change',
#        'current_debt_value_change', 'current_long_term_debt_value_change',
#        'current_net_receivables_value_change', 'deferred_revenue_value_change',
#        'depreciation_value_change',
#        'depreciation_and_amortization_value_change',
#        'depreciation_depletion_and_amortization_value_change',
#        'dividend_payout_value_change',
#        'dividend_payout_common_stock_value_change',
#        'dividend_payout_preferred_stock_value_change', 'ebit_value_change',
#        'ebitda_value_change', 'goodwill_value_change',
#        'gross_profit_value_change', 'income_before_tax_value_change',
#        'income_tax_expense_value_change', 'intangible_assets_value_change',
#        'intangible_assets_excluding_goodwill_value_change',
#        'interest_and_debt_expense_value_change',
#        'interest_expense_value_change', 'interest_income_value_change',
#        'inventory_value_change', 'investment_income_net_value_change',
#        'investments_value_change', 'long_term_debt_value_change',
#        'long_term_debt_noncurrent_value_change',
#        'long_term_investments_value_change', 'net_income_value_change',
#        'net_income_from_continuing_operations_value_change',
#        'net_interest_income_value_change', 'non_interest_income_value_change',
#        'operating_cashflow_value_change', 'operating_expenses_value_change',
#        'operating_income_value_change', 'other_current_assets_value_change',
#        'other_current_liabilities_value_change',
#        'other_non_current_assets_value_change',
#        'other_non_current_liabilities_value_change',
#        'other_non_operating_income_value_change',
#        'payments_for_operating_activities_value_change',
#        'payments_for_repurchase_of_common_stock_value_change',
#        'payments_for_repurchase_of_equity_value_change',
#        'payments_for_repurchase_of_preferred_stock_value_change',
#        'proceeds_from_issuance_of_common_stock_value_change',
#        'proceeds_from_issuance_of_long_term_debt_and_capital_securities_net_value_change',
#        'proceeds_from_issuance_of_preferred_stock_value_change',
#        'proceeds_from_operating_activities_value_change',
#        'proceeds_from_repayments_of_short_term_debt_value_change',
#        'proceeds_from_repurchase_of_equity_value_change',
#        'proceeds_from_sale_of_treasury_stock_value_change',
#        'profit_loss_value_change', 'property_plant_equipment_value_change',
#        'research_and_development_value_change',
#        'retained_earnings_value_change',
#        'selling_general_and_administrative_value_change',
#        'short_long_term_debt_total_value_change',
#        'short_term_debt_value_change', 'short_term_investments_value_change',
#        'total_assets_value_change', 'total_current_assets_value_change',
#        'total_current_liabilities_value_change',
#        'total_liabilities_value_change',
#        'total_non_current_assets_value_change',
#        'total_non_current_liabilities_value_change',
#        'total_revenue_value_change', 'total_shareholder_equity_value_change',
#        'treasury_stock_value_change', 'avg_interest_rate',
#        'avg_treasury_yield', 'avg_natural_gas_price', 'avg_oil_price',
#        'avg_unemployment_rate', 'avg_global_commodities_index_value',
#        'inflation', 'sector', 'avg_three_months_price',
#        'avg_next_three_months_price'],
#       dtype='object')

# %%
import datetime as dt


train_set, test_set = utils.split_data_to_train_and_test(
    df=dataset,
    cutoff_date=dt.datetime(2023,6,1)
)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49444 entries, 0 to 49443
# Data columns (total 97 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   change_in_cash_and_cash_equivalents                                               49444 non-null  float64
#  1   change_in_exchange_rate                                                           49444 non-null  float64
#  2   accumulated_depreciation_amortization_ppe_value_change                            49444 non-null  float64
#  3   capital_expenditures_value_change                                                 49444 non-null  float64
#  4   capital_lease_obligations_value_change                                            49444 non-null  float64
#  5   cash_and_cash_equivalents_at_carrying_value_value_change                          49444 non-null  float64
#  6   cash_and_short_term_investments_value_change                                      49444 non-null  float64
#  7   cashflow_from_financing_value_change                                              49444 non-null  float64
#  8   cashflow_from_investment_value_change                                             49444 non-null  float64
#  9   change_in_inventory_value_change                                                  49444 non-null  float64
#  10  change_in_operating_assets_value_change                                           49444 non-null  float64
#  11  change_in_operating_liabilities_value_change                                      49444 non-null  float64
#  12  change_in_receivables_value_change                                                49444 non-null  float64
#  13  common_stock_value_change                                                         49444 non-null  float64
#  14  common_stock_shares_outstanding_value_change                                      49444 non-null  float64
#  15  comprehensive_income_net_of_tax_value_change                                      49444 non-null  float64
#  16  cost_of_goods_and_services_sold_value_change                                      49444 non-null  float64
#  17  cost_of_revenue_value_change                                                      49444 non-null  float64
#  18  current_accounts_payable_value_change                                             49444 non-null  float64
#  19  current_debt_value_change                                                         49444 non-null  float64
#  20  current_long_term_debt_value_change                                               49444 non-null  float64
#  21  current_net_receivables_value_change                                              49444 non-null  float64
#  22  deferred_revenue_value_change                                                     49444 non-null  float64
#  23  depreciation_value_change                                                         49444 non-null  float64
#  24  depreciation_and_amortization_value_change                                        49444 non-null  float64
#  25  depreciation_depletion_and_amortization_value_change                              49444 non-null  float64
#  26  dividend_payout_value_change                                                      49444 non-null  float64
#  27  dividend_payout_common_stock_value_change                                         49444 non-null  float64
#  28  dividend_payout_preferred_stock_value_change                                      49444 non-null  float64
#  29  ebit_value_change                                                                 49444 non-null  float64
#  30  ebitda_value_change                                                               49444 non-null  float64
#  31  goodwill_value_change                                                             49444 non-null  float64
#  32  gross_profit_value_change                                                         49444 non-null  float64
#  33  income_before_tax_value_change                                                    49444 non-null  float64
#  34  income_tax_expense_value_change                                                   49444 non-null  float64
#  35  intangible_assets_value_change                                                    49444 non-null  float64
#  36  intangible_assets_excluding_goodwill_value_change                                 49444 non-null  float64
#  37  interest_and_debt_expense_value_change                                            49444 non-null  float64
#  38  interest_expense_value_change                                                     49444 non-null  float64
#  39  interest_income_value_change                                                      49444 non-null  float64
#  40  inventory_value_change                                                            49444 non-null  float64
#  41  investment_income_net_value_change                                                49444 non-null  float64
#  42  investments_value_change                                                          49444 non-null  float64
#  43  long_term_debt_value_change                                                       49444 non-null  float64
#  44  long_term_debt_noncurrent_value_change                                            49444 non-null  float64
#  45  long_term_investments_value_change                                                49444 non-null  float64
#  46  net_income_value_change                                                           49444 non-null  float64
#  47  net_income_from_continuing_operations_value_change                                49444 non-null  float64
#  48  net_interest_income_value_change                                                  49444 non-null  float64
#  49  non_interest_income_value_change                                                  49444 non-null  float64
#  50  operating_cashflow_value_change                                                   49444 non-null  float64
#  51  operating_expenses_value_change                                                   49444 non-null  float64
#  52  operating_income_value_change                                                     49444 non-null  float64
#  53  other_current_assets_value_change                                                 49444 non-null  float64
#  54  other_current_liabilities_value_change                                            49444 non-null  float64
#  55  other_non_current_assets_value_change                                             49444 non-null  float64
#  56  other_non_current_liabilities_value_change                                        49444 non-null  float64
#  57  other_non_operating_income_value_change                                           49444 non-null  float64
#  58  payments_for_operating_activities_value_change                                    49444 non-null  float64
#  59  payments_for_repurchase_of_common_stock_value_change                              49444 non-null  float64
#  60  payments_for_repurchase_of_equity_value_change                                    49444 non-null  float64
#  61  payments_for_repurchase_of_preferred_stock_value_change                           49444 non-null  float64
#  62  proceeds_from_issuance_of_common_stock_value_change                               49444 non-null  float64
#  63  proceeds_from_issuance_of_long_term_debt_and_capital_securities_net_value_change  49444 non-null  float64
#  64  proceeds_from_issuance_of_preferred_stock_value_change                            49444 non-null  float64
#  65  proceeds_from_operating_activities_value_change                                   49444 non-null  float64
#  66  proceeds_from_repayments_of_short_term_debt_value_change                          49444 non-null  float64
#  67  proceeds_from_repurchase_of_equity_value_change                                   49444 non-null  float64
#  68  proceeds_from_sale_of_treasury_stock_value_change                                 49444 non-null  float64
#  69  profit_loss_value_change                                                          49444 non-null  float64
#  70  property_plant_equipment_value_change                                             49444 non-null  float64
#  71  research_and_development_value_change                                             49444 non-null  float64
#  72  retained_earnings_value_change                                                    49444 non-null  float64
#  73  selling_general_and_administrative_value_change                                   49444 non-null  float64
#  74  short_long_term_debt_total_value_change                                           49444 non-null  float64
#  75  short_term_debt_value_change                                                      49444 non-null  float64
#  76  short_term_investments_value_change                                               49444 non-null  float64
#  77  total_assets_value_change                                                         49444 non-null  float64
#  78  total_current_assets_value_change                                                 49444 non-null  float64
#  79  total_current_liabilities_value_change                                            49444 non-null  float64
#  80  total_liabilities_value_change                                                    49444 non-null  float64
#  81  total_non_current_assets_value_change                                             49444 non-null  float64
#  82  total_non_current_liabilities_value_change                                        49444 non-null  float64
#  83  total_revenue_value_change                                                        49444 non-null  float64
#  84  total_shareholder_equity_value_change                                             49444 non-null  float64
#  85  treasury_stock_value_change                                                       49444 non-null  float64
#  86  avg_interest_rate                                                                 49444 non-null  float64
#  87  avg_treasury_yield                                                                49444 non-null  float64
#  88  avg_natural_gas_price                                                             49444 non-null  float64
#  89  avg_oil_price                                                                     49444 non-null  float64
#  90  avg_unemployment_rate                                                             49444 non-null  float64
#  91  avg_global_commodities_index_value                                                49444 non-null  float64
#  92  inflation                                                                         49444 non-null  float64
#  93  fiscal_date_ending                                                                49444 non-null  object
#  94  sector                                                                            49444 non-null  object
#  95  avg_three_months_price                                                            49444 non-null  float64
#  96  avg_next_three_months_price                                                       49444 non-null  float64
# dtypes: float64(95), object(2)
# memory usage: 36.6+ MB

# %%
test_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3189 entries, 0 to 3188
# Data columns (total 97 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   change_in_cash_and_cash_equivalents                                               3189 non-null   float64
#  1   change_in_exchange_rate                                                           3189 non-null   float64
#  2   accumulated_depreciation_amortization_ppe_value_change                            3189 non-null   float64
#  3   capital_expenditures_value_change                                                 3189 non-null   float64
#  4   capital_lease_obligations_value_change                                            3189 non-null   float64
#  5   cash_and_cash_equivalents_at_carrying_value_value_change                          3189 non-null   float64
#  6   cash_and_short_term_investments_value_change                                      3189 non-null   float64
#  7   cashflow_from_financing_value_change                                              3189 non-null   float64
#  8   cashflow_from_investment_value_change                                             3189 non-null   float64
#  9   change_in_inventory_value_change                                                  3189 non-null   float64
#  10  change_in_operating_assets_value_change                                           3189 non-null   float64
#  11  change_in_operating_liabilities_value_change                                      3189 non-null   float64
#  12  change_in_receivables_value_change                                                3189 non-null   float64
#  13  common_stock_value_change                                                         3189 non-null   float64
#  14  common_stock_shares_outstanding_value_change                                      3189 non-null   float64
#  15  comprehensive_income_net_of_tax_value_change                                      3189 non-null   float64
#  16  cost_of_goods_and_services_sold_value_change                                      3189 non-null   float64
#  17  cost_of_revenue_value_change                                                      3189 non-null   float64
#  18  current_accounts_payable_value_change                                             3189 non-null   float64
#  19  current_debt_value_change                                                         3189 non-null   float64
#  20  current_long_term_debt_value_change                                               3189 non-null   float64
#  21  current_net_receivables_value_change                                              3189 non-null   float64
#  22  deferred_revenue_value_change                                                     3189 non-null   float64
#  23  depreciation_value_change                                                         3189 non-null   float64
#  24  depreciation_and_amortization_value_change                                        3189 non-null   float64
#  25  depreciation_depletion_and_amortization_value_change                              3189 non-null   float64
#  26  dividend_payout_value_change                                                      3189 non-null   float64
#  27  dividend_payout_common_stock_value_change                                         3189 non-null   float64
#  28  dividend_payout_preferred_stock_value_change                                      3189 non-null   float64
#  29  ebit_value_change                                                                 3189 non-null   float64
#  30  ebitda_value_change                                                               3189 non-null   float64
#  31  goodwill_value_change                                                             3189 non-null   float64
#  32  gross_profit_value_change                                                         3189 non-null   float64
#  33  income_before_tax_value_change                                                    3189 non-null   float64
#  34  income_tax_expense_value_change                                                   3189 non-null   float64
#  35  intangible_assets_value_change                                                    3189 non-null   float64
#  36  intangible_assets_excluding_goodwill_value_change                                 3189 non-null   float64
#  37  interest_and_debt_expense_value_change                                            3189 non-null   float64
#  38  interest_expense_value_change                                                     3189 non-null   float64
#  39  interest_income_value_change                                                      3189 non-null   float64
#  40  inventory_value_change                                                            3189 non-null   float64
#  41  investment_income_net_value_change                                                3189 non-null   float64
#  42  investments_value_change                                                          3189 non-null   float64
#  43  long_term_debt_value_change                                                       3189 non-null   float64
#  44  long_term_debt_noncurrent_value_change                                            3189 non-null   float64
#  45  long_term_investments_value_change                                                3189 non-null   float64
#  46  net_income_value_change                                                           3189 non-null   float64
#  47  net_income_from_continuing_operations_value_change                                3189 non-null   float64
#  48  net_interest_income_value_change                                                  3189 non-null   float64
#  49  non_interest_income_value_change                                                  3189 non-null   float64
#  50  operating_cashflow_value_change                                                   3189 non-null   float64
#  51  operating_expenses_value_change                                                   3189 non-null   float64
#  52  operating_income_value_change                                                     3189 non-null   float64
#  53  other_current_assets_value_change                                                 3189 non-null   float64
#  54  other_current_liabilities_value_change                                            3189 non-null   float64
#  55  other_non_current_assets_value_change                                             3189 non-null   float64
#  56  other_non_current_liabilities_value_change                                        3189 non-null   float64
#  57  other_non_operating_income_value_change                                           3189 non-null   float64
#  58  payments_for_operating_activities_value_change                                    3189 non-null   float64
#  59  payments_for_repurchase_of_common_stock_value_change                              3189 non-null   float64
#  60  payments_for_repurchase_of_equity_value_change                                    3189 non-null   float64
#  61  payments_for_repurchase_of_preferred_stock_value_change                           3189 non-null   float64
#  62  proceeds_from_issuance_of_common_stock_value_change                               3189 non-null   float64
#  63  proceeds_from_issuance_of_long_term_debt_and_capital_securities_net_value_change  3189 non-null   float64
#  64  proceeds_from_issuance_of_preferred_stock_value_change                            3189 non-null   float64
#  65  proceeds_from_operating_activities_value_change                                   3189 non-null   float64
#  66  proceeds_from_repayments_of_short_term_debt_value_change                          3189 non-null   float64
#  67  proceeds_from_repurchase_of_equity_value_change                                   3189 non-null   float64
#  68  proceeds_from_sale_of_treasury_stock_value_change                                 3189 non-null   float64
#  69  profit_loss_value_change                                                          3189 non-null   float64
#  70  property_plant_equipment_value_change                                             3189 non-null   float64
#  71  research_and_development_value_change                                             3189 non-null   float64
#  72  retained_earnings_value_change                                                    3189 non-null   float64
#  73  selling_general_and_administrative_value_change                                   3189 non-null   float64
#  74  short_long_term_debt_total_value_change                                           3189 non-null   float64
#  75  short_term_debt_value_change                                                      3189 non-null   float64
#  76  short_term_investments_value_change                                               3189 non-null   float64
#  77  total_assets_value_change                                                         3189 non-null   float64
#  78  total_current_assets_value_change                                                 3189 non-null   float64
#  79  total_current_liabilities_value_change                                            3189 non-null   float64
#  80  total_liabilities_value_change                                                    3189 non-null   float64
#  81  total_non_current_assets_value_change                                             3189 non-null   float64
#  82  total_non_current_liabilities_value_change                                        3189 non-null   float64
#  83  total_revenue_value_change                                                        3189 non-null   float64
#  84  total_shareholder_equity_value_change                                             3189 non-null   float64
#  85  treasury_stock_value_change                                                       3189 non-null   float64
#  86  avg_interest_rate                                                                 3189 non-null   float64
#  87  avg_treasury_yield                                                                3189 non-null   float64
#  88  avg_natural_gas_price                                                             3189 non-null   float64
#  89  avg_oil_price                                                                     3189 non-null   float64
#  90  avg_unemployment_rate                                                             3189 non-null   float64
#  91  avg_global_commodities_index_value                                                3189 non-null   float64
#  92  inflation                                                                         3189 non-null   float64
#  93  fiscal_date_ending                                                                3189 non-null   object
#  94  sector                                                                            3189 non-null   object
#  95  avg_three_months_price                                                            3189 non-null   float64
#  96  avg_next_three_months_price                                                       3189 non-null   float64
# dtypes: float64(95), object(2)
# memory usage: 2.4+ MB

# %%
y_train = train_set[['avg_next_three_months_price', 'sector']]
X_train = train_set.drop(['avg_next_three_months_price'], axis=1)

y_test = test_set[['avg_next_three_months_price', 'sector']]
X_test = test_set.drop(['avg_next_three_months_price'], axis=1)

# %%
from sklearn.preprocessing import (
    OneHotEncoder,
)

one_hot_encoder = OneHotEncoder()

X_train_transformed = utils.transform_input(
    X=X_train,
    one_hot_encoder=one_hot_encoder,
    fit=True
)

X_test_transformed = utils.transform_input(
    X=X_test,
    one_hot_encoder=one_hot_encoder,
    fit=False
)

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest_regr = RandomForestRegressor(n_estimators=100)

random_forest_regr.fit(X_train_transformed, y_train['avg_next_three_months_price'])

# Make predictions using the testing set
y_pred_rf = pd.Series(random_forest_regr.predict(X_test_transformed))

# %%
from sklearn.metrics import mean_absolute_percentage_error, r2_score, mean_absolute_error

# The mean squared error
print("Mean absolute error: %.2f" % mean_absolute_error(y_test['avg_next_three_months_price'], y_pred_rf))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test['avg_next_three_months_price'], y_pred_rf))
print("Mean absolute pct error: %.2f" % mean_absolute_percentage_error(y_test['avg_next_three_months_price'], y_pred_rf))
# Out:
# Mean absolute error: 6.37
# Coefficient of determination: 0.97
# Mean absolute pct error: 0.13

# %%
utils.calculate_avg_pct_loss_per_sector(
    y_pred=y_pred_rf,
    y_actual=y_test['avg_next_three_months_price'],
    # y_pred=y_test['avg_next_three_months_price'],
    # y_actual=y_pred_rf,
    sector_series=y_test['sector']
)
# Out:
# {'MANUFACTURING': 0.12164958654503585,
#  'LIFE SCIENCES': 0.19791071353856526,
#  'TRADE & SERVICES': 0.1475747442936356,
#  'TECHNOLOGY': 0.11318599876649903,
#  'FINANCE': 0.08687217920728653,
#  'ENERGY & TRANSPORTATION': 0.1150310468238148,
#  'REAL ESTATE & CONSTRUCTION': 0.10173205224725565}

# %%
utils.get_feature_importance_sorted(
    feature_importance_scores=random_forest_regr.feature_importances_,
    feature_names=random_forest_regr.feature_names_in_
)
# Out:
# [('avg_three_months_price', 0.9715616744357627),
#  ('common_stock_shares_outstanding_value_change', 0.0036088518806861023),
#  ('other_current_liabilities_value_change', 0.0015974911440723842),
#  ('short_term_investments_value_change', 0.0013337330145527773),
#  ('avg_oil_price', 0.0013276948839551416),
#  ('investments_value_change', 0.0009601592620496372),
#  ('avg_natural_gas_price', 0.0005785545865728654),
#  ('capital_lease_obligations_value_change', 0.0005107163355619238),
#  ('avg_treasury_yield', 0.00048681878119731444),
#  ('avg_global_commodities_index_value', 0.00045724397803616624),
#  ('total_current_assets_value_change', 0.00042925508151854243),
#  ('change_in_operating_assets_value_change', 0.00042866856951121347),
#  ('sector_REAL ESTATE & CONSTRUCTION', 0.0004206700119974058),
#  ('total_revenue_value_change', 0.0004156352683536201),
#  ('retained_earnings_value_change', 0.0004156238362974992),
#  ('depreciation_depletion_and_amortization_value_change',
#   0.0003773763680451207),
#  ('capital_expenditures_value_change', 0.00036781985223743256),
#  ('cash_and_short_term_investments_value_change', 0.00036624505588617927),
#  ('research_and_development_value_change', 0.00036316180820391756),
#  ('cashflow_from_financing_value_change', 0.0003567404062585288),
#  ('deferred_revenue_value_change', 0.0003528487130907646),
#  ('depreciation_and_amortization_value_change', 0.0003428835338955587),
#  ('change_in_receivables_value_change', 0.0003370101692244232),
#  ('avg_unemployment_rate', 0.0003321086984536689),
#  ('common_stock_value_change', 0.0003248115137815569),
#  ('cost_of_goods_and_services_sold_value_change', 0.0003033057325766762),
#  ('interest_income_value_change', 0.00030151851597262505),
#  ('total_non_current_liabilities_value_change', 0.0002987369017491343),
#  ('proceeds_from_operating_activities_value_change', 0.0002792429133752292),
#  ('total_shareholder_equity_value_change', 0.00027556483964328085),
#  ('comprehensive_income_net_of_tax_value_change', 0.0002567443651525384),
#  ('cost_of_revenue_value_change', 0.0002513701364705942),
#  ('treasury_stock_value_change', 0.000251227612202801),
#  ('other_non_current_liabilities_value_change', 0.0002466004560530215),
#  ('property_plant_equipment_value_change', 0.00024225688827390898),
#  ('other_current_assets_value_change', 0.00023454770993613697),
#  ('dividend_payout_value_change', 0.0002318977250221672),
#  ('selling_general_and_administrative_value_change', 0.00022258389690449094),
#  ('total_liabilities_value_change', 0.00022227836646293865),
#  ('other_non_current_assets_value_change', 0.0002210129340817136),
#  ('cashflow_from_investment_value_change', 0.00022064712006155342),
#  ('change_in_cash_and_cash_equivalents', 0.0002165096796562859),
#  ('change_in_operating_liabilities_value_change', 0.00021243300184632706),
#  ('proceeds_from_repurchase_of_equity_value_change', 0.00020837677710416235),
#  ('total_non_current_assets_value_change', 0.0002077611111203352),
#  ('operating_income_value_change', 0.00020024294793787134),
#  ('net_interest_income_value_change', 0.00019804841894075704),
#  ('income_tax_expense_value_change', 0.00019797537614249123),
#  ('change_in_inventory_value_change', 0.00019336012835652713),
#  ('current_net_receivables_value_change', 0.00019270794167786903),
#  ('short_long_term_debt_total_value_change', 0.00019237899479088763),
#  ('payments_for_operating_activities_value_change', 0.00018994776332663214),
#  ('net_income_from_continuing_operations_value_change',
#   0.00018633179794867385),
#  ('inflation', 0.00018633011425485217),
#  ('operating_expenses_value_change', 0.0001842320344869531),
#  ('cash_and_cash_equivalents_at_carrying_value_value_change',
#   0.0001830368483468851),
#  ('long_term_investments_value_change', 0.00018127038811002592),
#  ('inventory_value_change', 0.0001761141331247462),
#  ('intangible_assets_excluding_goodwill_value_change', 0.00017593498037217506),
#  ('total_current_liabilities_value_change', 0.00017426289307567326),
#  ('sector_MANUFACTURING', 0.00017175911569282165),
#  ('operating_cashflow_value_change', 0.00017067387355232304),
#  ('depreciation_value_change', 0.00017028387816875196),
#  ('payments_for_repurchase_of_common_stock_value_change',
#   0.00016870777074542778),
#  ('profit_loss_value_change', 0.00016603623831442827),
#  ('total_assets_value_change', 0.00016347492048976442),
#  ('net_income_value_change', 0.00016306014776871494),
#  ('goodwill_value_change', 0.00015868088687627947),
#  ('current_accounts_payable_value_change', 0.00015631903333515317),
#  ('income_before_tax_value_change', 0.00015254649465994643),
#  ('long_term_debt_value_change', 0.00015214296827180626),
#  ('dividend_payout_common_stock_value_change', 0.0001484799424452335),
#  ('interest_and_debt_expense_value_change', 0.00014069791418148294),
#  ('gross_profit_value_change', 0.00014029035470132487),
#  ('current_long_term_debt_value_change', 0.00013922162247227026),
#  ('ebitda_value_change', 0.00013672809737880423),
#  ('interest_expense_value_change', 0.00013448299910625279),
#  ('non_interest_income_value_change', 0.00012993077804875032),
#  ('intangible_assets_value_change', 0.0001270642956966388),
#  ('other_non_operating_income_value_change', 0.0001239002882167493),
#  ('short_term_debt_value_change', 0.000120606588165597),
#  ('avg_interest_rate', 0.00011806385059222435),
#  ('ebit_value_change', 0.0001175562601635996),
#  ('investment_income_net_value_change', 0.0001152271761044312),
#  ('sector_TECHNOLOGY', 0.0001080944766775679),
#  ('payments_for_repurchase_of_equity_value_change', 9.448475867284609e-05),
#  ('long_term_debt_noncurrent_value_change', 9.345520798180033e-05),
#  ('accumulated_depreciation_amortization_ppe_value_change',
#   9.150558638810585e-05),
#  ('proceeds_from_issuance_of_common_stock_value_change',
#   7.624298161533637e-05),
#  ('current_debt_value_change', 7.539715641412603e-05),
#  ('proceeds_from_issuance_of_long_term_debt_and_capital_securities_net_value_change',
#   5.852641434489124e-05),
#  ('proceeds_from_repayments_of_short_term_debt_value_change',
#   5.213492605635444e-05),
#  ('change_in_exchange_rate', 2.469914577602181e-05),
#  ('sector_TRADE & SERVICES', 1.6169106257551132e-05),
#  ('sector_ENERGY & TRANSPORTATION', 1.4777116988213378e-05),
#  ('sector_LIFE SCIENCES', 1.4372224487591816e-05),
#  ('proceeds_from_issuance_of_preferred_stock_value_change',
#   1.3459909251553303e-05),
#  ('sector_FINANCE', 7.540817239050536e-06),
#  ('dividend_payout_preferred_stock_value_change', 1.6466588864350844e-06),
#  ('proceeds_from_sale_of_treasury_stock_value_change', 5.064682650188667e-07),
#  ('payments_for_repurchase_of_preferred_stock_value_change',
#   4.6291578738198627e-07)]

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

xgb_regressor = xgb.XGBRegressor(
        objective = 'reg:squarederror',
        n_estimators = 100,
        learning_rate = 0.1,
)

xgb_regressor.fit(X_train_transformed, y_train['avg_next_three_months_price'])

# Make predictions using the testing set
y_pred_xgb = pd.Series(xgb_regressor.predict(X_test_transformed))

# %%
from sklearn.metrics import mean_absolute_percentage_error, r2_score, mean_absolute_error

# The mean squared error
print("Mean absolute error: %.2f" % mean_absolute_error(y_test['avg_next_three_months_price'], y_pred_xgb))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test['avg_next_three_months_price'], y_pred_xgb))
print("Mean absolute pct error: %.2f" % mean_absolute_percentage_error(y_test['avg_next_three_months_price'], y_pred_xgb))
# Out:
# Mean absolute error: 7.49
# Coefficient of determination: 0.95
# Mean absolute pct error: 0.16
